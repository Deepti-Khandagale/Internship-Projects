# %%
import pandas as pd

# %%
df=pd.read_csv("/content/New Job Descriptions.csv", on_bad_lines='skip', engine='python')

# %%
df.shape
# Out:
# (8785, 23)

# %%
columns_to_keep = ['Job Id', 'Job Title', 'Company', 'location', 'Job Description', 'Experience', 'Qualifications', 'Salary Range', 'Work Type','skills']
df = df[columns_to_keep]

# %%
df.head(10)
# Out:
#          Job Id                     Job Title  \
# 0  1.089840e+15  Digital Marketing Specialist
# 1  3.984540e+14                 Web Developer
# 2  4.816400e+14            Operations Manager
# 3  6.881930e+14              Network Engineer
# 4  1.170580e+14                 Event Manager
# 5  1.168310e+14               Software Tester
# 6  1.292170e+15                       Teacher
# 7  1.498780e+15                UX/UI Designer
# 8  1.680290e+15                UX/UI Designer
# 9  2.556280e+14               Wedding Planner
#
#                                  Company      location  \
# 0                      Icahn Enterprises       Douglas
# 1           PNC Financial Services Group      Ashgabat
# 2       United Services Automobile Assn.         Macao
# 3                                   Hess    Porto-Novo
# 4                           Cairn Energy      Santiago
# 5  Adani Ports and Special Economic Zone      Brussels
# 6                                  FedEx   George Town
# ...

# %%
df.to_csv('/content/New Job Descriptions.csv', index=False)

# %%
df.isnull().sum()
# Out:
# Job Id             0
# Job Title          0
# Company            0
# location           0
# Job Description    0
# Experience         0
# Qualifications     0
# Salary Range       0
# Work Type          0
# skills             0
# dtype: int64
